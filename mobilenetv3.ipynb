# %%
# DeepLabv3+ with MobileNet_V3 Backbone

# %% [markdown]
# ## Ground Truth Visualizations

# %% [markdown]
# Let's visualized a few images and their segmentation masks from the training data, with
# the `keras_cv.visualization.plot_segmentation_mask_gallery` API.

# %% [markdown]
# Intersection over Union (IoU) is a metric often used in segmentation problems to assess the model's accuracy. It provides a more intuitive basis for accuracy that is not biased by the (unbalanced) percentage of pixels from any particular class. Given two segmentation masks, `A` and `B`, the IoU is defined as follows:
#
# $$
# IoU = \frac{|A\cap B\hspace{1mm}|}{|A\cup B\hspace{1mm}|} \hspace{2mm}
# $$
#
# When there are multiple classes and inferences, we assess the model's performance by computing the mean IoU.
#
# The function below computes the mean IoU that only considers the classes that are present in the ground truth mask or the predicted segmentation map (sometimes referred to as classwise mean IoU). This computation is a better representation of the metric since it only considers the relevant classes. **This is the metric computation we use for mean IoU.**

# %%
# Install necessary package
# !pip install -q git+https://github.com/keras-team/keras-cv.git --upgrade

# Import necessary libraries
import os
import requests
from zipfile import ZipFile
import glob
from dataclasses import dataclass

import random
import numpy as np
import cv2

import tensorflow as tf
import keras_cv

import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# WARNING: Error parsing requirements for aiohttp: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/aiohttp-3.9.1.dist-info/METADATA'

# %%
# System configuration function
def system_config(SEED_VALUE):
    random.seed(SEED_VALUE)
    tf.keras.utils.set_random_seed(SEED_VALUE)
    os.environ["CUDA_VISIBLE_DEVICES"] = '0'
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'     
    os.environ['TF_USE_CUDNN'] = "true"

system_config(SEED_VALUE=42)

# %%
# Download and unzip function
def download_and_unzip(url, save_path):
    print("Downloading and extracting assets...", end="")
    file = requests.get(url)
    open(save_path, "wb").write(file.content)
    try:
        if save_path.endswith(".zip"):
            with ZipFile(save_path) as zip:
                zip.extractall(os.path.split(save_path)[0])
        print("Done")
    except:
        print("Invalid file")

# %%
# Download dataset if it does not exist
DATASET_URL = r"https://www.dropbox.com/scl/fi/9k8t9619b4x0hegued5c5/Water-Bodies-Dataset.zip?rlkey=tjgepcai6t74yynmx7tqsm7af&dl=1"
DATASET_DIR = "Water-Bodies-Dataset"
DATASET_ZIP_PATH = os.path.join(os.getcwd(), f"{DATASET_DIR}.zip")
if not os.path.exists(DATASET_DIR):
    download_and_unzip(DATASET_URL, DATASET_ZIP_PATH)
    os.remove(DATASET_ZIP_PATH)

# %%
# Dataset configuration
@dataclass(frozen=True)
class DatasetConfig:
    IMAGE_SIZE: tuple = (256, 256)
    BATCH_SIZE: int = 8
    NUM_CLASSES: int = 2
    BRIGHTNESS_FACTOR: float = 0.2
    CONTRAST_FACTOR: float = 0.2

# %%
@dataclass(frozen=True)
class TrainingConfig:
    MODEL: str = "mobilenet_v3_large_imagenet"
    EPOCHS: int = 45
    LEARNING_RATE: float = 1e-4
    FINE_TUNE_LEARNING_RATE: float = 1e-5  
    CKPT_DIR: str = os.path.join("checkpoints", "deeplabv3_plus_" + "_".join(MODEL.split("_")[:2]) + ".weights.h5")
    LOGS_DIR: str = "logs_" + "_".join(MODEL.split("_")[:2])
    

train_config = TrainingConfig()
data_config = DatasetConfig()

# %%
data_images = glob.glob(os.path.join(DATASET_DIR, "Images", "*.jpg"))
data_masks = glob.glob(os.path.join(DATASET_DIR, "Masks", "*.jpg"))

# %%
import os
import glob
import tensorflow as tf
import os
from PIL import Image


# Function to load dataset with supported image file formats
def load_dataset(images_dir, masks_dir, img_extensions=("*.jpg"), mask_extensions=("*.jpg")):
    images = []
    masks = []
    for ext in img_extensions:
        image_files = glob.glob(os.path.join(images_dir, ext))
        image_files = [f for f in image_files if not f.endswith('.DS_Store')]
        images.extend(image_files)
    for ext in mask_extensions:
        masks_files = glob.glob(os.path.join(masks_dir, ext))
        masks_files = [f for f in masks_files if not f.endswith('.DS_Store')]
        masks.extend(masks_files)
    return sorted(images), sorted(masks)



# Additional dataset directories
additional_images_dir = "/kaggle/input/flood-w/archive/Image"
additional_masks_dir = "/kaggle/input/flood-w/archive/Mask"

# Load existing dataset
existing_data_images = data_images
existing_data_masks = data_masks 

# Load additional dataset
# additional_data_images, additional_data_masks = load_dataset(additional_images_dir, additional_masks_dir)

# Merge datasets
#data_images = existing_data_images + additional_data_images
#data_masks = existing_data_masks + additional_data_masks

# Ensure the number of images and masks match
assert len(data_images) == len(data_masks), "Number of images and masks do not match!"

# Print summary
print(f"Total images: {len(data_images)}")
print(f"Total masks: {len(data_masks)}")
# Out:
# Total images: 2841
# Total masks: 2841

# %%
# Shuffle and split dataset
zipped_data = list(zip(data_images, data_masks))
random.shuffle(zipped_data)
data_images, data_masks = zip(*zipped_data)
data_images = list(data_images)
data_masks = list(data_masks)

org_data = tf.data.Dataset.from_tensor_slices((data_images, data_masks))
SPLIT_RATIO = 0.1
NUM_VAL = int(len(data_images) * SPLIT_RATIO)
train_data = org_data.skip(2 * NUM_VAL)
valid_data = org_data.skip(NUM_VAL).take(NUM_VAL)
test_data = org_data.take(NUM_VAL)

# %%
# Functions to read and process images and masks
def read_image_mask(image_path, mask=False, size=data_config.IMAGE_SIZE):
    image = tf.io.read_file(image_path)
    if mask:
        image = tf.image.decode_jpeg(image, channels=1)
        image.set_shape([None, None, 1])
        image = tf.image.resize(images=image, size=size, method="bicubic")
        image_mask = tf.zeros_like(image)
        cond = image >= 200
        updates = tf.ones_like(image[cond])
        image_mask = tf.tensor_scatter_nd_update(image_mask, tf.where(cond), updates)
        image = tf.cast(image_mask, tf.uint8)
    else:
        image = tf.image.decode_jpeg(image, channels=3)
        image.set_shape([None, None, 3])
        image = tf.image.resize(images=image, size=size, method="bicubic")
        image = tf.cast(tf.clip_by_value(image, 0., 255.), tf.float32)
    return image

def load_data(image_list, mask_list):
    image = read_image_mask(image_list)
    mask = read_image_mask(mask_list, mask=True)
    return {"images": image, "segmentation_masks": mask}

# %%
# Create datasets
train_ds = train_data.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
valid_ds = valid_data.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
test_ds = test_data.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)

# %%
# Function to unpack inputs
def unpackage_inputs(inputs):
    images = inputs["images"]
    segmentation_masks = inputs["segmentation_masks"]
    return images, segmentation_masks

# %%
# Dictionary mapping class IDs to colors
id2color = {
    0: (0, 0, 0),        # Background
    1: (102, 204, 255),  # Waterbody
}

# %%
# Functions for image and mask visualization
def num_to_rgb(num_arr, color_map=id2color):
    output = np.zeros(num_arr.shape[:2] + (3,))
    for k in color_map.keys():
        output[num_arr == k] = color_map[k]
    return output.astype(np.uint8)

def image_overlay(image, segmented_image):
    alpha = 1.0
    beta = 0.7
    gamma = 0.0
    image = image.astype(np.uint8)
    segmented_image = cv2.cvtColor(segmented_image, cv2.COLOR_RGB2BGR)
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    image = cv2.addWeighted(image, alpha, segmented_image, beta, gamma, image)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

def display_image_and_mask(data_list, title_list, figsize, color_mask=False, color_map=id2color):
    rgb_gt_mask = num_to_rgb(data_list[1], color_map=color_map)
    mask_to_overlay = rgb_gt_mask
    if len(data_list) == 3:
        rgb_pred_mask = num_to_rgb(data_list[-1], color_map=color_map)
        mask_to_overlay = rgb_pred_mask
    overlayed_image = image_overlay(data_list[0], mask_to_overlay)
    data_list.append(overlayed_image)
    title_list.append("Overlayed Image")  # Add the title for the overlayed image
    fig, axes = plt.subplots(nrows=1, ncols=len(data_list), figsize=figsize)
    for idx, axis in enumerate(axes.flat):
        axis.set_title(title_list[idx])
        if title_list[idx] == "GT Mask":
            if color_mask:
                axis.imshow(rgb_gt_mask)
            else:
                axis.imshow(data_list[1], cmap="gray")
        elif title_list[idx] == "Pred Mask":
            if color_mask:
                axis.imshow(rgb_pred_mask)
            else:
                axis.imshow(data_list[-1], cmap="gray")
        else:
            axis.imshow(data_list[idx])
        axis.axis('off')
    plt.show()

# %%
# Visualize dataset
plot_train_ds = train_ds.map(unpackage_inputs).batch(4)
image_batch, mask_batch = next(iter(plot_train_ds.take(1)))
titles = ["GT Image", "GT Mask", "Overlayed Mask"]
for image, gt_mask in zip(image_batch, mask_batch):
    gt_mask = tf.squeeze(gt_mask, axis=-1).numpy()
    display_image_and_mask([image.numpy().astype(np.uint8), gt_mask], title_list=titles, figsize=(16, 6), color_mask=True)

# %%
# Data augmentation
augment_fn = tf.keras.Sequential(
    [
        keras_cv.layers.RandomFlip(),
        keras_cv.layers.RandomBrightness(factor=data_config.BRIGHTNESS_FACTOR, value_range=(0, 255)),
        keras_cv.layers.RandomContrast(factor=data_config.CONTRAST_FACTOR, value_range=(0, 255)),
    ]
)
train_dataset = (
    train_ds.shuffle(data_config.BATCH_SIZE)
    .map(augment_fn, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(data_config.BATCH_SIZE)
    .map(unpackage_inputs)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)
valid_dataset = (
    valid_ds.batch(data_config.BATCH_SIZE)
    .map(unpackage_inputs)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)
test_dataset = (
    test_ds.batch(data_config.BATCH_SIZE)
    .map(unpackage_inputs)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

# %%
# Visualize augmented dataset
image_batch, aug_mask_batch = next(iter(train_dataset.take(1)))
for idx, (image, gt_mask) in enumerate(zip(image_batch, aug_mask_batch)):
    if idx == 1:
        break
    gt_mask = tf.squeeze(gt_mask, axis=-1).numpy()
    display_image_and_mask([image.numpy().astype(np.uint8), gt_mask], title_list=titles, figsize=(16, 6), color_mask=False)

# %%
# Load backbone and build model
backbone = keras_cv.models.MobileNetV3Backbone.from_preset(
    preset=train_config.MODEL,
    
    input_shape=data_config.IMAGE_SIZE + (3,),
    load_weights=True
)
model1 = keras_cv.models.segmentation.DeepLabV3Plus(num_classes=data_config.NUM_CLASSES, backbone=backbone)
# print(model.summary())
# Out:
# Attaching 'config.json' from model 'keras/mobilenetv3/keras/mobilenet_v3_large_imagenet/2' to your Kaggle notebook...
# Attaching 'config.json' from model 'keras/mobilenetv3/keras/mobilenet_v3_large_imagenet/2' to your Kaggle notebook...
# Attaching 'model.weights.h5' from model 'keras/mobilenetv3/keras/mobilenet_v3_large_imagenet/2' to your Kaggle notebook...

# %%
input_shape=data_config.IMAGE_SIZE + (3,),

# %%
from tensorflow.keras.layers import Input, Average
from tensorflow.keras.models import Model

# %%
input_shape = (256, 256, 3)

# %%
# Mean IOU metric
def mean_iou(y_true, y_pred):
    num_classes = y_pred.shape[-1]
    y_true = tf.squeeze(y_true, axis=-1)
    y_true = tf.one_hot(tf.cast(y_true, tf.int32), num_classes, axis=-1)
    y_pred = tf.one_hot(tf.math.argmax(y_pred, axis=-1), num_classes, axis=-1)
    intersection = tf.math.reduce_sum(y_true * y_pred, axis=(1, 2))
    total = tf.math.reduce_sum(y_true, axis=(1, 2)) + tf.math.reduce_sum(y_pred, axis=(1, 2))
    union = total - intersection
    is_class_present = tf.cast(tf.math.not_equal(total, 0), dtype=tf.float32)
    num_classes_present = tf.math.reduce_sum(is_class_present, axis=1)
    iou = tf.math.divide_no_nan(intersection, union)
    iou = tf.math.reduce_sum(iou, axis=1) / num_classes_present
    mean_iou = tf.math.reduce_mean(iou)
    return mean_iou

# %%
# Callbacks

def get_callbacks(train_config, monitor="val_mean_iou", mode="max", save_weights_only=True, save_best_only=True, patience=5):
    tensorboard_callback = tf.keras.callbacks.TensorBoard(
        log_dir=train_config.LOGS_DIR,
        histogram_freq=20,
        write_graph=False,
        update_freq="epoch",  # Set update_freq to 'epoch'
    )
    checkpoint_filepath = train_config.CKPT_DIR
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=save_weights_only,
        monitor=monitor,
        mode=mode,
        save_best_only=save_best_only,
        verbose=1,
        # patience=patience  # Add patience parameter
    )
    return [tensorboard_callback, model_checkpoint_callback]

# %%
# Define precision, recall, f1_score, and mse functions
def precision(y_true, y_pred):
    y_pred = tf.argmax(y_pred, axis=-1)
    y_true = tf.squeeze(y_true, axis=-1)
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    true_positives = tf.reduce_sum(y_true * y_pred)
    predicted_positives = tf.reduce_sum(y_pred)
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    return precision

def recall(y_true, y_pred):
    y_pred = tf.argmax(y_pred, axis=-1)
    y_true = tf.squeeze(y_true, axis=-1)
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    true_positives = tf.reduce_sum(y_true * y_pred)
    possible_positives = tf.reduce_sum(y_true)
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    return recall

def f1_score(y_true, y_pred):
    prec = precision(y_true, y_pred)
    rec = recall(y_true, y_pred)
    return 2 * (prec * rec) / (prec + rec + tf.keras.backend.epsilon())

def mse(y_true, y_pred):
    return tf.keras.losses.MeanSquaredError()(y_true, y_pred)

# %%
# Build model
callbacks = get_callbacks(train_config)
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)


model1.compile(
    optimizer=tf.keras.optimizers.Adam(train_config.LEARNING_RATE),
    loss=loss_fn,
    metrics=["accuracy", mean_iou, precision, recall, f1_score, mse],
)

# %%
# Training the model
history = model1.fit(
    train_dataset,
    epochs=train_config.EPOCHS,
    validation_data=valid_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.7720 - f1_score: 0.6686 - loss: 0.4946 - mean_iou: 0.5521 - mse: 0.3615 - precision: 0.6828 - recall: 0.6902
# Epoch 1: val_mean_iou improved from -inf to 0.64019, saving model to checkpoints/deeplabv3_plus_mobilenet_v3.weights.h5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 92s 203ms/step - accuracy: 0.7722 - f1_score: 0.6687 - loss: 0.4943 - mean_iou: 0.5523 - mse: 0.3615 - precision: 0.6830 - recall: 0.6902 - val_accuracy: 0.8263 - val_f1_score: 0.7285 - val_loss: 0.3840 - val_mean_iou: 0.6402 - val_mse: 0.3956 - val_precision: 0.6718 - val_recall: 0.8112
# Epoch 2/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8671 - f1_score: 0.7787 - loss: 0.3164 - mean_iou: 0.6941 - mse: 0.4032 - precision: 0.8354 - recall: 0.7416
# Epoch 2: val_mean_iou improved from 0.64019 to 0.68972, saving model to checkpoints/deeplabv3_plus_mobilenet_v3.weights.h5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 186ms/step - accuracy: 0.8671 - f1_score: 0.7787 - loss: 0.3164 - mean_iou: 0.6941 - mse: 0.4032 - precision: 0.8354 - recall: 0.7416 - val_accuracy: 0.8670 - val_f1_score: 0.7821 - val_loss: 0.3292 - val_mean_iou: 0.6897 - val_mse: 0.4320 - val_precision: 0.7416 - val_recall: 0.8360
# Epoch 3/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8884 - f1_score: 0.8163 - loss: 0.2753 - mean_iou: 0.7308 - mse: 0.4161 - precision: 0.8630 - recall: 0.7818
# Epoch 3: val_mean_iou improved from 0.68972 to 0.71316, saving model to checkpoints/deeplabv3_plus_mobilenet_v3.weights.h5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 187ms/step - accuracy: 0.8884 - f1_score: 0.8163 - loss: 0.2753 - mean_iou: 0.7308 - mse: 0.4161 - precision: 0.8630 - recall: 0.7818 - val_accuracy: 0.8729 - val_f1_score: 0.7844 - val_loss: 0.3122 - val_mean_iou: 0.7132 - val_mse: 0.4337 - val_precision: 0.7643 - val_recall: 0.8167
# Epoch 4/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8992 - f1_score: 0.8355 - loss: 0.2508 - mean_iou: 0.7487 - mse: 0.4203 - precision: 0.8707 - recall: 0.8087
# Epoch 4: val_mean_iou improved from 0.71316 to 0.73761, saving model to checkpoints/deeplabv3_plus_mobilenet_v3.weights.h5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 54s 188ms/step - accuracy: 0.8992 - f1_score: 0.8355 - loss: 0.2508 - mean_iou: 0.7487 - mse: 0.4204 - precision: 0.8707 - recall: 0.8087 - val_accuracy: 0.8905 - val_f1_score: 0.8084 - val_loss: 0.2671 - val_mean_iou: 0.7376 - val_mse: 0.4375 - val_precision: 0.8066 - val_recall: 0.8207
# Epoch 5/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9030 - f1_score: 0.8395 - loss: 0.2409 - mean_iou: 0.7586 - mse: 0.4231 - precision: 0.8767 - recall: 0.8109
# Epoch 5: val_mean_iou improved from 0.73761 to 0.75377, saving model to checkpoints/deeplabv3_plus_mobilenet_v3.weights.h5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 187ms/step - accuracy: 0.9030 - f1_score: 0.8395 - loss: 0.2409 - mean_iou: 0.7586 - mse: 0.4231 - precision: 0.8767 - recall: 0.8109 - val_accuracy: 0.9028 - val_f1_score: 0.8307 - val_loss: 0.2403 - val_mean_iou: 0.7538 - val_mse: 0.4322 - val_precision: 0.8113 - val_recall: 0.8566
# Epoch 6/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9075 - f1_score: 0.8469 - loss: 0.2299 - mean_iou: 0.7676 - mse: 0.4293 - precision: 0.8801 - recall: 0.8216
# Epoch 6: val_mean_iou improved from 0.75377 to 0.77255, saving model to checkpoints/deeplabv3_plus_mobilenet_v3.weights.h5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 187ms/step - accuracy: 0.9075 - f1_score: 0.8469 - loss: 0.2299 - mean_iou: 0.7676 - mse: 0.4293 - precision: 0.8801 - recall: 0.8216 - val_accuracy: 0.9092 - val_f1_score: 0.8385 - val_loss: 0.2239 - val_mean_iou: 0.7725 - val_mse: 0.4310 - val_precision: 0.8313 - val_recall: 0.8517
# Epoch 7/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9136 - f1_score: 0.8576 - loss: 0.2161 - mean_iou: 0.7791 - mse: 0.4329 - precision: 0.8910 - recall: 0.8325
# Epoch 7: val_mean_iou did not improve from 0.77255
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 184ms/step - accuracy: 0.9136 - f1_score: 0.8576 - loss: 0.2161 - mean_iou: 0.7792 - mse: 0.4329 - precision: 0.8910 - recall: 0.8325 - val_accuracy: 0.9149 - val_f1_score: 0.8399 - val_loss: 0.2196 - val_mean_iou: 0.7714 - val_mse: 0.4466 - val_precision: 0.8897 - val_recall: 0.8004
# Epoch 8/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9162 - f1_score: 0.8620 - loss: 0.2104 - mean_iou: 0.7876 - mse: 0.4347 - precision: 0.8949 - recall: 0.8360
# Epoch 8: val_mean_iou did not improve from 0.77255
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 184ms/step - accuracy: 0.9162 - f1_score: 0.8620 - loss: 0.2104 - mean_iou: 0.7876 - mse: 0.4347 - precision: 0.8949 - recall: 0.8360 - val_accuracy: 0.9143 - val_f1_score: 0.8436 - val_loss: 0.2190 - val_mean_iou: 0.7661 - val_mse: 0.4475 - val_precision: 0.8827 - val_recall: 0.8146
# Epoch 9/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9205 - f1_score: 0.8694 - loss: 0.2032 - mean_iou: 0.7898 - mse: 0.4370 - precision: 0.8987 - recall: 0.8458
# Epoch 9: val_mean_iou improved from 0.77255 to 0.77263, saving model to checkpoints/deeplabv3_plus_mobilenet_v3.weights.h5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 186ms/step - accuracy: 0.9205 - f1_score: 0.8694 - loss: 0.2032 - mean_iou: 0.7898 - mse: 0.4370 - precision: 0.8986 - recall: 0.8458 - val_accuracy: 0.9120 - val_f1_score: 0.8402 - val_loss: 0.2305 - val_mean_iou: 0.7726 - val_mse: 0.4519 - val_precision: 0.8787 - val_recall: 0.8126
# Epoch 10/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9225 - f1_score: 0.8720 - loss: 0.1907 - mean_iou: 0.7981 - mse: 0.4410 - precision: 0.9018 - recall: 0.8478
# Epoch 10: val_mean_iou improved from 0.77263 to 0.77391, saving model to checkpoints/deeplabv3_plus_mobilenet_v3.weights.h5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 54s 187ms/step - accuracy: 0.9225 - f1_score: 0.8720 - loss: 0.1907 - mean_iou: 0.7981 - mse: 0.4410 - precision: 0.9018 - recall: 0.8478 - val_accuracy: 0.9140 - val_f1_score: 0.8388 - val_loss: 0.2212 - val_mean_iou: 0.7739 - val_mse: 0.4470 - val_precision: 0.9076 - val_recall: 0.7866
# Epoch 11/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9260 - f1_score: 0.8788 - loss: 0.1855 - mean_iou: 0.8053 - mse: 0.4431 - precision: 0.9049 - recall: 0.8579
# Epoch 11: val_mean_iou improved from 0.77391 to 0.79077, saving model to checkpoints/deeplabv3_plus_mobilenet_v3.weights.h5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 54s 188ms/step - accuracy: 0.9260 - f1_score: 0.8788 - loss: 0.1855 - mean_iou: 0.8053 - mse: 0.4431 - precision: 0.9049 - recall: 0.8579 - val_accuracy: 0.9209 - val_f1_score: 0.8533 - val_loss: 0.2109 - val_mean_iou: 0.7908 - val_mse: 0.4541 - val_precision: 0.9107 - val_recall: 0.8088
# Epoch 12/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9297 - f1_score: 0.8847 - loss: 0.1770 - mean_iou: 0.8123 - mse: 0.4464 - precision: 0.9116 - recall: 0.8625
# Epoch 12: val_mean_iou did not improve from 0.79077
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 184ms/step - accuracy: 0.9297 - f1_score: 0.8847 - loss: 0.1770 - mean_iou: 0.8123 - mse: 0.4463 - precision: 0.9116 - recall: 0.8625 - val_accuracy: 0.9217 - val_f1_score: 0.8557 - val_loss: 0.2043 - val_mean_iou: 0.7899 - val_mse: 0.4522 - val_precision: 0.8983 - val_recall: 0.8226
# Epoch 13/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9316 - f1_score: 0.8883 - loss: 0.1771 - mean_iou: 0.8148 - mse: 0.4464 - precision: 0.9160 - recall: 0.8645
# Epoch 13: val_mean_iou improved from 0.79077 to 0.79299, saving model to checkpoints/deeplabv3_plus_mobilenet_v3.weights.h5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 54s 188ms/step - accuracy: 0.9316 - f1_score: 0.8883 - loss: 0.1771 - mean_iou: 0.8148 - mse: 0.4464 - precision: 0.9159 - recall: 0.8645 - val_accuracy: 0.9222 - val_f1_score: 0.8616 - val_loss: 0.2218 - val_mean_iou: 0.7930 - val_mse: 0.4547 - val_precision: 0.8841 - val_recall: 0.8451
# Epoch 14/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9281 - f1_score: 0.8829 - loss: 0.1812 - mean_iou: 0.8120 - mse: 0.4424 - precision: 0.9087 - recall: 0.8614
# Epoch 14: val_mean_iou did not improve from 0.79299
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 185ms/step - accuracy: 0.9282 - f1_score: 0.8829 - loss: 0.1812 - mean_iou: 0.8120 - mse: 0.4424 - precision: 0.9087 - recall: 0.8615 - val_accuracy: 0.9134 - val_f1_score: 0.8536 - val_loss: 0.2207 - val_mean_iou: 0.7829 - val_mse: 0.4522 - val_precision: 0.8300 - val_recall: 0.8833
# Epoch 15/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9330 - f1_score: 0.8898 - loss: 0.1678 - mean_iou: 0.8187 - mse: 0.4485 - precision: 0.9116 - recall: 0.8717
# Epoch 15: val_mean_iou did not improve from 0.79299
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 185ms/step - accuracy: 0.9330 - f1_score: 0.8898 - loss: 0.1678 - mean_iou: 0.8187 - mse: 0.4485 - precision: 0.9116 - recall: 0.8717 - val_accuracy: 0.9176 - val_f1_score: 0.8526 - val_loss: 0.2276 - val_mean_iou: 0.7878 - val_mse: 0.4537 - val_precision: 0.8679 - val_recall: 0.8430
# Epoch 16/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9367 - f1_score: 0.8975 - loss: 0.1600 - mean_iou: 0.8253 - mse: 0.4492 - precision: 0.9204 - recall: 0.8777
# Epoch 16: val_mean_iou did not improve from 0.79299
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 184ms/step - accuracy: 0.9367 - f1_score: 0.8975 - loss: 0.1599 - mean_iou: 0.8253 - mse: 0.4492 - precision: 0.9204 - recall: 0.8777 - val_accuracy: 0.9223 - val_f1_score: 0.8590 - val_loss: 0.2128 - val_mean_iou: 0.7904 - val_mse: 0.4550 - val_precision: 0.8955 - val_recall: 0.8304
# Epoch 17/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9345 - f1_score: 0.8935 - loss: 0.1636 - mean_iou: 0.8259 - mse: 0.4505 - precision: 0.9154 - recall: 0.8755
# Epoch 17: val_mean_iou improved from 0.79299 to 0.80989, saving model to checkpoints/deeplabv3_plus_mobilenet_v3.weights.h5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 54s 188ms/step - accuracy: 0.9345 - f1_score: 0.8935 - loss: 0.1635 - mean_iou: 0.8259 - mse: 0.4505 - precision: 0.9154 - recall: 0.8755 - val_accuracy: 0.9305 - val_f1_score: 0.8718 - val_loss: 0.1927 - val_mean_iou: 0.8099 - val_mse: 0.4608 - val_precision: 0.9069 - val_recall: 0.8435
# Epoch 18/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9387 - f1_score: 0.8996 - loss: 0.1526 - mean_iou: 0.8347 - mse: 0.4519 - precision: 0.9212 - recall: 0.8811
# Epoch 18: val_mean_iou did not improve from 0.80989
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 185ms/step - accuracy: 0.9387 - f1_score: 0.8996 - loss: 0.1526 - mean_iou: 0.8347 - mse: 0.4519 - precision: 0.9212 - recall: 0.8812 - val_accuracy: 0.9208 - val_f1_score: 0.8601 - val_loss: 0.2062 - val_mean_iou: 0.7928 - val_mse: 0.4529 - val_precision: 0.8647 - val_recall: 0.8600
# Epoch 19/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9372 - f1_score: 0.8984 - loss: 0.1570 - mean_iou: 0.8285 - mse: 0.4526 - precision: 0.9207 - recall: 0.8788
# Epoch 19: val_mean_iou did not improve from 0.80989
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 184ms/step - accuracy: 0.9372 - f1_score: 0.8984 - loss: 0.1570 - mean_iou: 0.8285 - mse: 0.4526 - precision: 0.9207 - recall: 0.8788 - val_accuracy: 0.9243 - val_f1_score: 0.8652 - val_loss: 0.2141 - val_mean_iou: 0.7947 - val_mse: 0.4613 - val_precision: 0.8776 - val_recall: 0.8565
# Epoch 20/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9411 - f1_score: 0.9049 - loss: 0.1491 - mean_iou: 0.8369 - mse: 0.4548 - precision: 0.9260 - recall: 0.8868
# Epoch 20: val_mean_iou did not improve from 0.80989
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 184ms/step - accuracy: 0.9411 - f1_score: 0.9049 - loss: 0.1491 - mean_iou: 0.8369 - mse: 0.4548 - precision: 0.9260 - recall: 0.8868 - val_accuracy: 0.9222 - val_f1_score: 0.8604 - val_loss: 0.2146 - val_mean_iou: 0.7935 - val_mse: 0.4561 - val_precision: 0.8859 - val_recall: 0.8431
# Epoch 21/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9420 - f1_score: 0.9054 - loss: 0.1460 - mean_iou: 0.8402 - mse: 0.4549 - precision: 0.9244 - recall: 0.8889
# Epoch 21: val_mean_iou did not improve from 0.80989
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 56s 195ms/step - accuracy: 0.9420 - f1_score: 0.9054 - loss: 0.1460 - mean_iou: 0.8402 - mse: 0.4549 - precision: 0.9244 - recall: 0.8889 - val_accuracy: 0.9208 - val_f1_score: 0.8559 - val_loss: 0.2290 - val_mean_iou: 0.7997 - val_mse: 0.4576 - val_precision: 0.8910 - val_recall: 0.8312
# Epoch 22/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9420 - f1_score: 0.9037 - loss: 0.1455 - mean_iou: 0.8406 - mse: 0.4549 - precision: 0.9242 - recall: 0.8859
# Epoch 22: val_mean_iou did not improve from 0.80989
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 52s 183ms/step - accuracy: 0.9420 - f1_score: 0.9037 - loss: 0.1455 - mean_iou: 0.8407 - mse: 0.4549 - precision: 0.9242 - recall: 0.8859 - val_accuracy: 0.9226 - val_f1_score: 0.8611 - val_loss: 0.2053 - val_mean_iou: 0.8007 - val_mse: 0.4553 - val_precision: 0.8686 - val_recall: 0.8582
# Epoch 23/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9400 - f1_score: 0.9021 - loss: 0.1481 - mean_iou: 0.8377 - mse: 0.4550 - precision: 0.9238 - recall: 0.8839
# Epoch 23: val_mean_iou did not improve from 0.80989
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 52s 184ms/step - accuracy: 0.9400 - f1_score: 0.9021 - loss: 0.1481 - mean_iou: 0.8377 - mse: 0.4550 - precision: 0.9238 - recall: 0.8839 - val_accuracy: 0.9289 - val_f1_score: 0.8677 - val_loss: 0.2102 - val_mean_iou: 0.8047 - val_mse: 0.4661 - val_precision: 0.9157 - val_recall: 0.8296
# Epoch 24/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9405 - f1_score: 0.9028 - loss: 0.1502 - mean_iou: 0.8405 - mse: 0.4557 - precision: 0.9229 - recall: 0.8864
# Epoch 24: val_mean_iou did not improve from 0.80989
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 185ms/step - accuracy: 0.9405 - f1_score: 0.9028 - loss: 0.1501 - mean_iou: 0.8405 - mse: 0.4557 - precision: 0.9229 - recall: 0.8864 - val_accuracy: 0.9116 - val_f1_score: 0.8439 - val_loss: 0.2566 - val_mean_iou: 0.7725 - val_mse: 0.4561 - val_precision: 0.8629 - val_recall: 0.8316
# Epoch 25/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9424 - f1_score: 0.9050 - loss: 0.1432 - mean_iou: 0.8413 - mse: 0.4558 - precision: 0.9247 - recall: 0.8881
# Epoch 25: val_mean_iou did not improve from 0.80989
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 185ms/step - accuracy: 0.9424 - f1_score: 0.9050 - loss: 0.1432 - mean_iou: 0.8414 - mse: 0.4558 - precision: 0.9247 - recall: 0.8881 - val_accuracy: 0.9119 - val_f1_score: 0.8532 - val_loss: 0.2294 - val_mean_iou: 0.7828 - val_mse: 0.4480 - val_precision: 0.8295 - val_recall: 0.8858
# Epoch 26/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9428 - f1_score: 0.9058 - loss: 0.1430 - mean_iou: 0.8431 - mse: 0.4566 - precision: 0.9239 - recall: 0.8910
# Epoch 26: val_mean_iou did not improve from 0.80989
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 185ms/step - accuracy: 0.9429 - f1_score: 0.9058 - loss: 0.1430 - mean_iou: 0.8431 - mse: 0.4566 - precision: 0.9239 - recall: 0.8910 - val_accuracy: 0.9148 - val_f1_score: 0.8527 - val_loss: 0.2257 - val_mean_iou: 0.7857 - val_mse: 0.4425 - val_precision: 0.8573 - val_recall: 0.8533
# Epoch 27/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9434 - f1_score: 0.9053 - loss: 0.1422 - mean_iou: 0.8432 - mse: 0.4555 - precision: 0.9254 - recall: 0.8881
# Epoch 27: val_mean_iou did not improve from 0.80989
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 186ms/step - accuracy: 0.9434 - f1_score: 0.9054 - loss: 0.1422 - mean_iou: 0.8432 - mse: 0.4555 - precision: 0.9254 - recall: 0.8881 - val_accuracy: 0.9285 - val_f1_score: 0.8758 - val_loss: 0.1996 - val_mean_iou: 0.8079 - val_mse: 0.4556 - val_precision: 0.8787 - val_recall: 0.8768
# Epoch 28/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9470 - f1_score: 0.9120 - loss: 0.1315 - mean_iou: 0.8546 - mse: 0.4596 - precision: 0.9279 - recall: 0.8984
# Epoch 28: val_mean_iou did not improve from 0.80989
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 184ms/step - accuracy: 0.9470 - f1_score: 0.9120 - loss: 0.1315 - mean_iou: 0.8547 - mse: 0.4596 - precision: 0.9279 - recall: 0.8984 - val_accuracy: 0.9284 - val_f1_score: 0.8734 - val_loss: 0.2022 - val_mean_iou: 0.8090 - val_mse: 0.4594 - val_precision: 0.8767 - val_recall: 0.8743
# Epoch 29/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9471 - f1_score: 0.9136 - loss: 0.1326 - mean_iou: 0.8541 - mse: 0.4599 - precision: 0.9305 - recall: 0.8988
# Epoch 29: val_mean_iou did not improve from 0.80989
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 185ms/step - accuracy: 0.9470 - f1_score: 0.9136 - loss: 0.1327 - mean_iou: 0.8541 - mse: 0.4599 - precision: 0.9305 - recall: 0.8987 - val_accuracy: 0.8912 - val_f1_score: 0.8245 - val_loss: 0.3065 - val_mean_iou: 0.7474 - val_mse: 0.4422 - val_precision: 0.7733 - val_recall: 0.8929
# Epoch 30/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9391 - f1_score: 0.9020 - loss: 0.1518 - mean_iou: 0.8370 - mse: 0.4537 - precision: 0.9231 - recall: 0.8840
# Epoch 30: val_mean_iou did not improve from 0.80989
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 185ms/step - accuracy: 0.9391 - f1_score: 0.9020 - loss: 0.1518 - mean_iou: 0.8370 - mse: 0.4537 - precision: 0.9231 - recall: 0.8841 - val_accuracy: 0.9045 - val_f1_score: 0.8197 - val_loss: 0.3023 - val_mean_iou: 0.7589 - val_mse: 0.4587 - val_precision: 0.8740 - val_recall: 0.7811
# Epoch 31/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9457 - f1_score: 0.9124 - loss: 0.1390 - mean_iou: 0.8502 - mse: 0.4584 - precision: 0.9320 - recall: 0.8948
# Epoch 31: val_mean_iou did not improve from 0.80989
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 82s 184ms/step - accuracy: 0.9457 - f1_score: 0.9124 - loss: 0.1390 - mean_iou: 0.8502 - mse: 0.4584 - precision: 0.9320 - recall: 0.8949 - val_accuracy: 0.9210 - val_f1_score: 0.8600 - val_loss: 0.2147 - val_mean_iou: 0.7951 - val_mse: 0.4552 - val_precision: 0.8604 - val_recall: 0.8651
# Epoch 32/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9486 - f1_score: 0.9163 - loss: 0.1296 - mean_iou: 0.8574 - mse: 0.4601 - precision: 0.9333 - recall: 0.9012
# Epoch 32: val_mean_iou improved from 0.80989 to 0.81609, saving model to checkpoints/deeplabv3_plus_mobilenet_v3.weights.h5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 187ms/step - accuracy: 0.9486 - f1_score: 0.9163 - loss: 0.1296 - mean_iou: 0.8574 - mse: 0.4601 - precision: 0.9333 - recall: 0.9013 - val_accuracy: 0.9303 - val_f1_score: 0.8754 - val_loss: 0.1883 - val_mean_iou: 0.8161 - val_mse: 0.4595 - val_precision: 0.8746 - val_recall: 0.8797
# Epoch 33/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9507 - f1_score: 0.9194 - loss: 0.1229 - mean_iou: 0.8624 - mse: 0.4623 - precision: 0.9354 - recall: 0.9053
# Epoch 33: val_mean_iou did not improve from 0.81609
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 185ms/step - accuracy: 0.9508 - f1_score: 0.9194 - loss: 0.1229 - mean_iou: 0.8624 - mse: 0.4623 - precision: 0.9354 - recall: 0.9053 - val_accuracy: 0.9284 - val_f1_score: 0.8724 - val_loss: 0.1911 - val_mean_iou: 0.8122 - val_mse: 0.4573 - val_precision: 0.8750 - val_recall: 0.8746
# Epoch 34/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9401 - f1_score: 0.9017 - loss: 0.1491 - mean_iou: 0.8383 - mse: 0.4554 - precision: 0.9229 - recall: 0.8837
# Epoch 34: val_mean_iou improved from 0.81609 to 0.81970, saving model to checkpoints/deeplabv3_plus_mobilenet_v3.weights.h5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 187ms/step - accuracy: 0.9402 - f1_score: 0.9017 - loss: 0.1490 - mean_iou: 0.8383 - mse: 0.4555 - precision: 0.9229 - recall: 0.8838 - val_accuracy: 0.9333 - val_f1_score: 0.8766 - val_loss: 0.1879 - val_mean_iou: 0.8197 - val_mse: 0.4617 - val_precision: 0.9043 - val_recall: 0.8562
# Epoch 35/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9500 - f1_score: 0.9174 - loss: 0.1250 - mean_iou: 0.8622 - mse: 0.4613 - precision: 0.9337 - recall: 0.9029
# Epoch 35: val_mean_iou did not improve from 0.81970
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 185ms/step - accuracy: 0.9500 - f1_score: 0.9174 - loss: 0.1250 - mean_iou: 0.8622 - mse: 0.4613 - precision: 0.9337 - recall: 0.9029 - val_accuracy: 0.9250 - val_f1_score: 0.8623 - val_loss: 0.2303 - val_mean_iou: 0.8061 - val_mse: 0.4568 - val_precision: 0.9090 - val_recall: 0.8267
# Epoch 36/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9495 - f1_score: 0.9163 - loss: 0.1264 - mean_iou: 0.8611 - mse: 0.4619 - precision: 0.9317 - recall: 0.9030
# Epoch 36: val_mean_iou improved from 0.81970 to 0.82188, saving model to checkpoints/deeplabv3_plus_mobilenet_v3.weights.h5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 54s 187ms/step - accuracy: 0.9495 - f1_score: 0.9163 - loss: 0.1263 - mean_iou: 0.8611 - mse: 0.4619 - precision: 0.9317 - recall: 0.9031 - val_accuracy: 0.9331 - val_f1_score: 0.8774 - val_loss: 0.1910 - val_mean_iou: 0.8219 - val_mse: 0.4652 - val_precision: 0.8968 - val_recall: 0.8642
# Epoch 37/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9517 - f1_score: 0.9198 - loss: 0.1224 - mean_iou: 0.8653 - mse: 0.4628 - precision: 0.9339 - recall: 0.9073
# Epoch 37: val_mean_iou improved from 0.82188 to 0.82749, saving model to checkpoints/deeplabv3_plus_mobilenet_v3.weights.h5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 187ms/step - accuracy: 0.9517 - f1_score: 0.9198 - loss: 0.1223 - mean_iou: 0.8653 - mse: 0.4628 - precision: 0.9339 - recall: 0.9073 - val_accuracy: 0.9349 - val_f1_score: 0.8842 - val_loss: 0.1862 - val_mean_iou: 0.8275 - val_mse: 0.4619 - val_precision: 0.8866 - val_recall: 0.8855
# Epoch 38/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9526 - f1_score: 0.9237 - loss: 0.1179 - mean_iou: 0.8671 - mse: 0.4638 - precision: 0.9392 - recall: 0.9099
# Epoch 38: val_mean_iou did not improve from 0.82749
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 186ms/step - accuracy: 0.9526 - f1_score: 0.9237 - loss: 0.1179 - mean_iou: 0.8671 - mse: 0.4638 - precision: 0.9392 - recall: 0.9099 - val_accuracy: 0.9255 - val_f1_score: 0.8626 - val_loss: 0.2049 - val_mean_iou: 0.8067 - val_mse: 0.4530 - val_precision: 0.8948 - val_recall: 0.8389
# Epoch 39/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9524 - f1_score: 0.9218 - loss: 0.1184 - mean_iou: 0.8658 - mse: 0.4637 - precision: 0.9380 - recall: 0.9073
# Epoch 39: val_mean_iou did not improve from 0.82749
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 185ms/step - accuracy: 0.9525 - f1_score: 0.9218 - loss: 0.1184 - mean_iou: 0.8658 - mse: 0.4637 - precision: 0.9379 - recall: 0.9073 - val_accuracy: 0.9285 - val_f1_score: 0.8721 - val_loss: 0.2044 - val_mean_iou: 0.8150 - val_mse: 0.4610 - val_precision: 0.8844 - val_recall: 0.8679
# Epoch 40/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9517 - f1_score: 0.9214 - loss: 0.1202 - mean_iou: 0.8649 - mse: 0.4633 - precision: 0.9360 - recall: 0.9082
# Epoch 40: val_mean_iou did not improve from 0.82749
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 186ms/step - accuracy: 0.9516 - f1_score: 0.9213 - loss: 0.1203 - mean_iou: 0.8649 - mse: 0.4633 - precision: 0.9360 - recall: 0.9082 - val_accuracy: 0.8760 - val_f1_score: 0.8103 - val_loss: 0.3339 - val_mean_iou: 0.7296 - val_mse: 0.4375 - val_precision: 0.7386 - val_recall: 0.9042
# Epoch 41/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9371 - f1_score: 0.8990 - loss: 0.1609 - mean_iou: 0.8335 - mse: 0.4541 - precision: 0.9236 - recall: 0.8788
# Epoch 41: val_mean_iou did not improve from 0.82749
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 55s 194ms/step - accuracy: 0.9371 - f1_score: 0.8990 - loss: 0.1609 - mean_iou: 0.8336 - mse: 0.4541 - precision: 0.9236 - recall: 0.8789 - val_accuracy: 0.9273 - val_f1_score: 0.8722 - val_loss: 0.1950 - val_mean_iou: 0.8132 - val_mse: 0.4576 - val_precision: 0.8675 - val_recall: 0.8805
# Epoch 42/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9520 - f1_score: 0.9222 - loss: 0.1209 - mean_iou: 0.8643 - mse: 0.4628 - precision: 0.9385 - recall: 0.9075
# Epoch 42: val_mean_iou did not improve from 0.82749
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 186ms/step - accuracy: 0.9520 - f1_score: 0.9222 - loss: 0.1209 - mean_iou: 0.8643 - mse: 0.4628 - precision: 0.9384 - recall: 0.9075 - val_accuracy: 0.9249 - val_f1_score: 0.8663 - val_loss: 0.2059 - val_mean_iou: 0.8123 - val_mse: 0.4611 - val_precision: 0.8774 - val_recall: 0.8602
# Epoch 43/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9536 - f1_score: 0.9250 - loss: 0.1159 - mean_iou: 0.8696 - mse: 0.4644 - precision: 0.9390 - recall: 0.9122
# Epoch 43: val_mean_iou did not improve from 0.82749
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 185ms/step - accuracy: 0.9536 - f1_score: 0.9250 - loss: 0.1159 - mean_iou: 0.8696 - mse: 0.4644 - precision: 0.9390 - recall: 0.9122 - val_accuracy: 0.9278 - val_f1_score: 0.8726 - val_loss: 0.1974 - val_mean_iou: 0.8119 - val_mse: 0.4574 - val_precision: 0.8797 - val_recall: 0.8695
# Epoch 44/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9506 - f1_score: 0.9206 - loss: 0.1225 - mean_iou: 0.8622 - mse: 0.4622 - precision: 0.9355 - recall: 0.9073
# Epoch 44: val_mean_iou did not improve from 0.82749
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 184ms/step - accuracy: 0.9506 - f1_score: 0.9206 - loss: 0.1224 - mean_iou: 0.8622 - mse: 0.4623 - precision: 0.9355 - recall: 0.9073 - val_accuracy: 0.9297 - val_f1_score: 0.8751 - val_loss: 0.1971 - val_mean_iou: 0.8167 - val_mse: 0.4590 - val_precision: 0.8784 - val_recall: 0.8760
# Epoch 45/45
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9532 - f1_score: 0.9239 - loss: 0.1167 - mean_iou: 0.8685 - mse: 0.4642 - precision: 0.9387 - recall: 0.9107
# Epoch 45: val_mean_iou did not improve from 0.82749
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 53s 186ms/step - accuracy: 0.9532 - f1_score: 0.9239 - loss: 0.1167 - mean_iou: 0.8685 - mse: 0.4642 - precision: 0.9387 - recall: 0.9107 - val_accuracy: 0.9251 - val_f1_score: 0.8664 - val_loss: 0.2039 - val_mean_iou: 0.8089 - val_mse: 0.4590 - val_precision: 0.8660 - val_recall: 0.8731

# %%
def precision(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
    predicted_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    return precision


def recall(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    return recall


def f1_score(y_true, y_pred):
    prec = precision(y_true, y_pred)
    rec = recall(y_true, y_pred)
    return 2 * (prec * rec) / (prec + rec + tf.keras.backend.epsilon())

def mse(y_true, y_pred):
    return tf.keras.losses.MeanSquaredError()(y_true, y_pred)

# Add these custom metrics to the model compilation
model1.compile(
    optimizer=tf.keras.optimizers.Adam(train_config.LEARNING_RATE),
    loss=loss_fn,
    metrics=["accuracy", mean_iou, precision, recall, f1_score, mse],
)

# %%
# Define a function to plot the metrics

def plot_metrics(history, metric_name, title):
    plt.figure(figsize=(9, 4))
    plt.plot(history.history[metric_name])
    plt.plot(history.history[f'val_{metric_name}'])
    plt.title(f'Model {title}')
    plt.xlabel('Epoch')
    plt.ylabel(metric_name.capitalize())
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.grid(True)
    plt.show()

# %%
# # Plot accuracy
# plot_metrics(history, 'accuracy', 'Accuracy')
# plt.savefig("Accuracy.png")

# %%
# plot_metrics(history, 'loss', 'Loss')
# plt.savefig("loss.png")

# %%
# # Plot mean IoU
# plot_metrics(history, 'mean_iou', 'Mean IoU')
# plt.savefig("mean IoU.png")

# %%
# # Plot precision
# plot_metrics(history, 'precision', 'Precision')
# plt.savefig("Precision.png")

# %%
# # Plot recall
# plot_metrics(history, 'recall', 'Recall')
# plt.savefig("recall.png")

# %%
# # Plot F1 score
# plot_metrics(history, 'f1_score', 'F1 Score')
# plt.savefig("F-1 Score.png")

# %%
# # Plot MSE
# plot_metrics(history, 'mse', 'Mean Squared Error')
# plt.savefig("MSE.png")

# %% [markdown]
# #### Load Fine-tuned Model Weights

# %%
print(len(test_ds))
print(len(train_ds))
print(len(valid_ds))
dataset_size=len(test_ds)+len(train_ds)+len(valid_ds)
print(f'\nTotal size of dataset : {dataset_size}')
# Out:
# 284
# 2273
# 284
#
# Total size of dataset : 2841

# %%
import tensorflow as tf
import numpy as np

# Combine training and validation datasets into a single evaluation dataset
eval_ds = test_ds.batch(data_config.BATCH_SIZE)

# Initialize accumulators for metrics
total_accuracy = 0.0
total_precision = 0.0
total_recall = 0.0
total_mse = 0.0
total_loss = 0.0
total_f1 = 0.0
total_iou = 0.0
total_samples = 0

# Define precision, recall, and F1 score functions
def precision(y_true, y_pred):
    y_pred = tf.argmax(y_pred, axis=-1)
    y_true = tf.squeeze(y_true, axis=-1)
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    true_positives = tf.reduce_sum(y_true * y_pred)
    predicted_positives = tf.reduce_sum(y_pred)
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    return precision

def recall(y_true, y_pred):
    y_pred = tf.argmax(y_pred, axis=-1)
    y_true = tf.squeeze(y_true, axis=-1)
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    true_positives = tf.reduce_sum(y_true * y_pred)
    possible_positives = tf.reduce_sum(y_true)
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    return recall

def f1_score(y_true, y_pred):
    prec = precision(y_true, y_pred)
    rec = recall(y_true, y_pred)
    return 2 * (prec * rec) / (prec + rec + tf.keras.backend.epsilon())

# IoU calculation function
def iou(y_true, y_pred):
    y_pred = tf.argmax(y_pred, axis=-1)
    y_true = tf.squeeze(y_true, axis=-1)
    y_pred = tf.cast(y_pred, tf.float32)
    y_true = tf.cast(y_true, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(tf.cast(tf.math.logical_or(tf.cast(y_true, tf.bool), tf.cast(y_pred, tf.bool)), tf.float32))
    iou = (intersection + tf.keras.backend.epsilon()) / (union + tf.keras.backend.epsilon())
    return iou

# Evaluation loop
for batch in eval_ds:
    imgs, masks = batch['images'], batch['segmentation_masks']
    total_samples += imgs.shape[0]

    # Make predictions
    prediction = model1(imgs, training=False)
    pred_masks = tf.argmax(prediction, axis=-1)
    pred_masks = tf.expand_dims(pred_masks, axis=-1)

    # Calculate loss
    loss = loss_fn(masks, prediction)

    # Calculate metrics
    total_loss += loss.numpy() * imgs.shape[0]
    total_accuracy += tf.keras.metrics.SparseCategoricalAccuracy()(masks, prediction).numpy() * imgs.shape[0]
    total_precision += precision(masks, prediction).numpy() * imgs.shape[0]
    total_recall += recall(masks, prediction).numpy() * imgs.shape[0]
    total_mse += tf.keras.losses.MeanSquaredError()(tf.cast(masks, tf.float32), tf.cast(pred_masks, tf.float32)).numpy() * imgs.shape[0]
    total_f1 += f1_score(masks, prediction).numpy() * imgs.shape[0]
    total_iou += iou(masks, prediction).numpy() * imgs.shape[0]

# Compute overall metrics
overall_accuracy = total_accuracy / total_samples
overall_precision = total_precision / total_samples
overall_recall = total_recall / total_samples
overall_mse = total_mse / total_samples
overall_loss = total_loss / total_samples
overall_f1 = total_f1 / total_samples
overall_iou = total_iou / total_samples

print(f"Overall Accuracy on test: {overall_accuracy}")
print(f"Overall Precision on test: {overall_precision}")
print(f"Overall Recall on test: {overall_recall}")
print(f"Overall MSE on test: {overall_mse}")
print(f"Overall Loss on test: {overall_loss}")
print(f"Overall F1 Score on test: {overall_f1}")
print(f"Overall IoU on test: {overall_iou}")
# Out:
# Overall Accuracy on test: 0.926924315976425
# Overall Precision on test: 0.8783393628160718
# Overall Recall on test: 0.8781549376501164
# Overall MSE on test: 0.07307568402357505
# Overall Loss on test: 0.1931625068397589
# Overall F1 Score on test: 0.8755336538167067
# Overall IoU on test: 0.7827699646143846

# %%
# Evaluate the model on the test dataset
# test_results = model.evaluate(test_dataset)

# print(f"Test Results - Loss: {test_results[0]} - Accuracy: {test_results[1]} - Mean IOU: {test_results[2]}")

# Function to predict and display results on test dataset
def predict_and_display(ensemble_model, test_dataset, num_images=4):
    for image_batch, mask_batch in test_dataset.take(1):
        pred_mask_batch = ensemble_model.predict(image_batch)
        for i in range(num_images):
            image = image_batch[i].numpy().astype(np.uint8)
            gt_mask = tf.squeeze(mask_batch[i], axis=-1).numpy()
            pred_mask = tf.argmax(pred_mask_batch[i], axis=-1).numpy()
            display_image_and_mask([image, gt_mask, pred_mask], title_list=["Image", "GT Mask", "Pred Mask"], figsize=(18, 6), color_mask=True)

# Predict and display results on the test dataset
predict_and_display(model1, test_dataset)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
model1.load_weights(train_config.CKPT_DIR)

# %% [markdown]
# #### Perform Evaluation

# %%
print(len(valid_dataset))
print(len(train_dataset))
print(len(test_dataset))
# Out:
# 36
# 285
# 36

# %%
evaluate = model1.evaluate(valid_dataset)
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9348 - f1_score: 0.8913 - loss: 0.1795 - mean_iou: 0.8261 - mse: 0.4620 - precision: 0.3178 - recall: 1.0000

# %%
evaluate = model1.evaluate(test_dataset)
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9269 - f1_score: 0.8678 - loss: 0.1978 - mean_iou: 0.8131 - mse: 0.4614 - precision: 0.2974 - recall: 1.0000

# %%
def inference(model, dataset, samples_to_plot):

    num_batches_to_process = 2
    count = 0
    stop_plot = False

    titles = ["Image", "GT Mask", "Pred Mask", "Overlayed Prediction"]

    for idx, data in enumerate(dataset):

        if stop_plot:
            break

        batch_img, batch_mask = data[0], data[1]
        batch_pred = (model.predict(batch_img)).astype('float32')
        batch_pred = batch_pred.argmax(axis=-1)
        
        batch_img  = batch_img.numpy().astype('uint8')
        batch_mask = batch_mask.numpy().squeeze(axis=-1)

        for image, mask, pred in zip(batch_img, batch_mask, batch_pred):
            count+=1
            display_image_and_mask([image, mask, pred],
                                  title_list=titles,
                                   figsize=(20,8),
                                   color_mask=True)
            if count >= samples_to_plot:
                stop_plot=True
                break

# %%
inference(model1, valid_dataset, samples_to_plot=6)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
